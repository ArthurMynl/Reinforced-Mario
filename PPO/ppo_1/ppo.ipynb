# %% [markdown]
# # 1. Setup Mario
# Basic mario environment setup, with random actions.

# %%
from nes_py.wrappers import JoypadSpace
import gym
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
env = gym.make('SuperMarioBros-v0', apply_api_compatibility=True, render_mode="human")
env = JoypadSpace(env, SIMPLE_MOVEMENT)

done = True
for step in range(2000):
    if done:
       state = env.reset()
    action = env.action_space.sample()
    state, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
env.close()
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %% [markdown]
# # 2. Preprocessing Data

# %% [markdown]
# ## 2.1 What the environment is giving us

# %%
# Number of possible actions the AI can make
env.action_space
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Number of possible actions the AI can make
# ----> 2 env.action_space
#
# NameError: name 'env' is not defined

# %%
# The format returned by the environment : A colored frame
env.observation_space.shape
# Out:
# (240, 256, 3)

# %% [markdown]
# ## 2.2 What we want
# - Turn the image into grayscale
# - Save a stack of 4 images to give context to the model

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# %pip install stable-baselines3[extra]
# %pip install matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from nes_py.wrappers import JoypadSpace
JoypadSpace.reset = lambda self, **kwargs: self.env.reset(**kwargs)
import gym
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed
from matplotlib import pyplot as plt

# %%
FRAME_STACK_SIZE = 4

# %% [markdown]
# Basic environment

# %%
# Base environment
env = gym.make('SuperMarioBros-v0', apply_api_compatibility=True)
# Simplify controls
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# Grayscale observation
env = GrayScaleObservation(env, keep_dim=True)
# Wrap inside the dummy vector environment
env = DummyVecEnv([lambda: env])
# Stack 4 frames
env = VecFrameStack(env, n_stack=FRAME_STACK_SIZE, channels_order='last')

# %% [markdown]
# Multiprocessed environment

# %%
env_id = "SuperMarioBros-v0"
num_processes = 8

# %%
def make_env(env_id: str, rank: int, seed: int = None):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = gym.make(env_id, apply_api_compatibility=True)
        env = JoypadSpace(env, SIMPLE_MOVEMENT)
        env = GrayScaleObservation(env, keep_dim=True)
        return env
    return _init

# %%
# Create n environments
env = DummyVecEnv([make_env(env_id, i) for i in range(num_processes)])
# Stack 4 frames
env = VecFrameStack(env, n_stack=FRAME_STACK_SIZE, channels_order='last')
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
state = env.reset()
state[0].shape
# Out:
# (240, 256, 4)

# %%
action = env.action_space.sample()
state, reward, done, info = env.step([action])
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 action = env.action_space.sample()
# ----> 2 state, reward, done, info = env.step([action])
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:33, in VecFrameStack.step_wait(self)
#      30 def step_wait(
#      31     self,
#      32 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 33     observations, rewards, dones, infos = self.venv.step_wait()
#      34     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      35     return observations, rewards, dones, infos
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
#      58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# IndexError: list index out of range

# %%
# show the 4 current frames
plt.figure(figsize=(10, 8))
for idk in range(state.shape[3]):
    plt.subplot(1, 4, idk + 1)
    plt.imshow(state[0, :, :, idk], cmap='gray')
plt.show()

# %% [markdown]
# # 3. Training the model

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback

# %%
# class to automatically save models while training
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
    
    def _init_callback(self) -> None:
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            self.model.save(os.path.join(self.save_path, f"model_{self.n_calls * num_processes}"))
        
        return True

# %%
CHECKPOINT_DIR = "./train"
LOG_DIR = "./logs"

# %%
# setup the callback
callback = TrainAndLoggingCallback(check_freq=10000 / num_processes, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ## New model

# %%
# create the model
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, n_steps=512)

# train the model
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs\PPO_12
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 190  |
# |    iterations      | 1    |
# |    time_elapsed    | 21   |
# |    total_timesteps | 4096 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 2            |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0003632751 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00144     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 79.2         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -9.89e-05    |
# |    value_loss           | 234          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 107           |
# |    iterations           | 3             |
# |    time_elapsed         | 114           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00090533495 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0947        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 15.7          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000658     |
# |    value_loss           | 34.6          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 4           |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004602304 |
# |    clip_fraction        | 0.001       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.296       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 0.76        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 5            |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0010321868 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.162        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000757    |
# |    value_loss           | 0.474        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 6            |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0011597698 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.107        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.349        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 7           |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.000177498 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0769      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -3.82e-05   |
# |    value_loss           | 0.284       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 8            |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0013995281 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.124        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 0.243        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 9            |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0008815973 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.0333       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0906       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000672    |
# |    value_loss           | 0.224        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 103           |
# |    iterations           | 10            |
# |    time_elapsed         | 395           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00022583424 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.00408       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0687        |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000115     |
# |    value_loss           | 0.18          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 11           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0034376993 |
# |    clip_fraction        | 0.00374      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | -0.00784     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0747       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 12            |
# |    time_elapsed         | 478           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00061191316 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.88         |
# |    explained_variance   | 0.0101        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0528        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000459     |
# |    value_loss           | 0.135         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 13           |
# |    time_elapsed         | 520          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0010500096 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.0125       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0622       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000909    |
# |    value_loss           | 0.116        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 14           |
# |    time_elapsed         | 560          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0024767583 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | -0.0165      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0326       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 0.126        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 15          |
# |    time_elapsed         | 601         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.000666711 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.00489     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0687      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000351   |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 16            |
# |    time_elapsed         | 640           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00031660282 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.86         |
# |    explained_variance   | 0.000765      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0318        |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -7.95e-05     |
# |    value_loss           | 0.105         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 17          |
# |    time_elapsed         | 679         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007503613 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 24.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00221     |
# |    value_loss           | 87.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 18           |
# |    time_elapsed         | 721          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0052023195 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 32.8         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.000174     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 19           |
# |    time_elapsed         | 760          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0020721303 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.142        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00059     |
# |    value_loss           | 0.445        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 20          |
# |    time_elapsed         | 802         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005233784 |
# |    clip_fraction        | 0.00796     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.108       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 0.431       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 21           |
# |    time_elapsed         | 842          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0031475537 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.116        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 0.312        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 22           |
# |    time_elapsed         | 884          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0029226225 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.15         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.295        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 23           |
# |    time_elapsed         | 925          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0044300444 |
# |    clip_fraction        | 0.00862      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 20.6         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 57.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 24          |
# |    time_elapsed         | 964         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.001098574 |
# |    clip_fraction        | 0.00183     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 16          |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000483   |
# |    value_loss           | 32.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 25           |
# |    time_elapsed         | 1006         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0028203623 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.474        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 0.487        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 26          |
# |    time_elapsed         | 1046        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005194823 |
# |    clip_fraction        | 0.00337     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.158       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 0.414       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 27          |
# |    time_elapsed         | 1087        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.000693788 |
# |    clip_fraction        | 0.000586    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0869      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000426   |
# |    value_loss           | 0.34        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 28          |
# |    time_elapsed         | 1127        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008292938 |
# |    clip_fraction        | 0.00454     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0675      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 0.199       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 29           |
# |    time_elapsed         | 1165         |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0029347017 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0495       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 0.159        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 30          |
# |    time_elapsed         | 1206        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.002358571 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0439      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000704   |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 31            |
# |    time_elapsed         | 1244          |
# |    total_timesteps      | 126976        |
# | train/                  |               |
# |    approx_kl            | 0.00080087857 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.73         |
# |    explained_variance   | 0.931         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.109         |
# |    n_updates            | 300           |
# |    policy_gradient_loss | 6.79e-05      |
# |    value_loss           | 0.237         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 32           |
# |    time_elapsed         | 1285         |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0015814273 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0833       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000666    |
# |    value_loss           | 13.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 33          |
# |    time_elapsed         | 1324        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.007381808 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 39.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.000651    |
# |    value_loss           | 174         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 34           |
# |    time_elapsed         | 1363         |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0046437457 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.62        |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 22           |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 37.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 35          |
# |    time_elapsed         | 1404        |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.015099948 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0358      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00554    |
# |    value_loss           | 0.257       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 36           |
# |    time_elapsed         | 1443         |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0051002186 |
# |    clip_fraction        | 0.00178      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 12.7         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000471    |
# |    value_loss           | 22           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 37          |
# |    time_elapsed         | 1484        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.001194983 |
# |    clip_fraction        | 0.00154     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 7.09        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 18.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 38           |
# |    time_elapsed         | 1523         |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0047967755 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.055        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 0.193        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 39           |
# |    time_elapsed         | 1563         |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0029992135 |
# |    clip_fraction        | 0.000269     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 7.35         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000987    |
# |    value_loss           | 33.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 40           |
# |    time_elapsed         | 1604         |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0048523126 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.141        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 0.208        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 41           |
# |    time_elapsed         | 1643         |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0016828434 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0707       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000644    |
# |    value_loss           | 0.208        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 42          |
# |    time_elapsed         | 1684        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.010711831 |
# |    clip_fraction        | 0.00176     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.107       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000944   |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 43          |
# |    time_elapsed         | 1724        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.013091687 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0627      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 0.16        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 44          |
# |    time_elapsed         | 1766        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.003759115 |
# |    clip_fraction        | 0.00154     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0642      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000939   |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 45          |
# |    time_elapsed         | 1806        |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.013185618 |
# |    clip_fraction        | 0.0186      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0745      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 0.164       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 46         |
# |    time_elapsed         | 1846       |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.00683445 |
# |    clip_fraction        | 0.00322    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.436      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.163      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00161   |
# |    value_loss           | 0.16       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 47           |
# |    time_elapsed         | 1888         |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0029914603 |
# |    clip_fraction        | 0.00803      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.532        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0783       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000982    |
# |    value_loss           | 0.163        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 48          |
# |    time_elapsed         | 1927        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004511724 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.156       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.000491   |
# |    value_loss           | 6.19        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 49           |
# |    time_elapsed         | 1968         |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0018044478 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 81.8         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000127    |
# |    value_loss           | 187          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 50          |
# |    time_elapsed         | 2007        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.004401839 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 1.4         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000898   |
# |    value_loss           | 5.52        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 51         |
# |    time_elapsed         | 2046       |
# |    total_timesteps      | 208896     |
# | train/                  |            |
# |    approx_kl            | 0.00542425 |
# |    clip_fraction        | 0.00754    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.125      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0011    |
# |    value_loss           | 0.225      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 52          |
# |    time_elapsed         | 2088        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.002086007 |
# |    clip_fraction        | 0.000293    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 7.04        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.000967   |
# |    value_loss           | 29.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 53          |
# |    time_elapsed         | 2127        |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.008926734 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.345       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 1.58        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 54           |
# |    time_elapsed         | 2167         |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0035936208 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0947       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 5.49         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 55           |
# |    time_elapsed         | 2206         |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0074302945 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 5.97         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 23.4         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 102        |
# |    iterations           | 56         |
# |    time_elapsed         | 2245       |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.00800441 |
# |    clip_fraction        | 0.0202     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.12       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.00263   |
# |    value_loss           | 0.21       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 57           |
# |    time_elapsed         | 2286         |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0066448012 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0767       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 0.219        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 58          |
# |    time_elapsed         | 2327        |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.007431322 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.151       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 0.216       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 59          |
# |    time_elapsed         | 2368        |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.016401868 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0635      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 0.172       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 60           |
# |    time_elapsed         | 2407         |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0135461595 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0678       |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 0.145        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 61           |
# |    time_elapsed         | 2446         |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0030646967 |
# |    clip_fraction        | 2.44e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.537        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 22.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 62           |
# |    time_elapsed         | 2487         |
# |    total_timesteps      | 253952       |
# | train/                  |              |
# |    approx_kl            | 0.0053358446 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.37         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 26.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 63          |
# |    time_elapsed         | 2526        |
# |    total_timesteps      | 258048      |
# | train/                  |             |
# |    approx_kl            | 0.011208569 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.175       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00334    |
# ...
# |    total_timesteps      | 921600       |
# | train/                  |              |
# |    approx_kl            | 0.0015325749 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 174          |
# |    n_updates            | 2240         |
# |    policy_gradient_loss | -0.000715    |
# |    value_loss           | 425          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 226          |
# |    time_elapsed         | 9216         |
# |    total_timesteps      | 925696       |
# | train/                  |              |
# |    approx_kl            | 0.0018027952 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 118          |
# |    n_updates            | 2250         |
# |    policy_gradient_loss | -0.000277    |
# |    value_loss           | 411          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 227          |
# |    time_elapsed         | 9260         |
# |    total_timesteps      | 929792       |
# | train/                  |              |
# |    approx_kl            | 0.0015619386 |
# |    clip_fraction        | 0.00181      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 114          |
# |    n_updates            | 2260         |
# |    policy_gradient_loss | -0.000181    |
# |    value_loss           | 414          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 228          |
# |    time_elapsed         | 9306         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0024840091 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 95           |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.000415    |
# |    value_loss           | 355          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 229          |
# |    time_elapsed         | 9351         |
# |    total_timesteps      | 937984       |
# | train/                  |              |
# |    approx_kl            | 0.0026629767 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 94.5         |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.000949    |
# |    value_loss           | 419          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 230          |
# |    time_elapsed         | 9397         |
# |    total_timesteps      | 942080       |
# | train/                  |              |
# |    approx_kl            | 0.0010593317 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.791        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 241          |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.000421    |
# |    value_loss           | 404          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 231          |
# |    time_elapsed         | 9441         |
# |    total_timesteps      | 946176       |
# | train/                  |              |
# |    approx_kl            | 0.0017688826 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 128          |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 303          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 232          |
# |    time_elapsed         | 9487         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0021591575 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.584       |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 78.6         |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | 0.000266     |
# |    value_loss           | 329          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 233          |
# |    time_elapsed         | 9531         |
# |    total_timesteps      | 954368       |
# | train/                  |              |
# |    approx_kl            | 0.0020959743 |
# |    clip_fraction        | 0.00774      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 147          |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.000657    |
# |    value_loss           | 373          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 234          |
# |    time_elapsed         | 9574         |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0016827418 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.725       |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 66.1         |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 439          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 235         |
# |    time_elapsed         | 9621        |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.000964609 |
# |    clip_fraction        | 0.00298     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 63.3        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.000926   |
# |    value_loss           | 270         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 236         |
# |    time_elapsed         | 9663        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.002157108 |
# |    clip_fraction        | 0.00684     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 118         |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 448         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 237          |
# |    time_elapsed         | 9708         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0027946816 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.89         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 109          |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 361          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 238          |
# |    time_elapsed         | 9749         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0026230598 |
# |    clip_fraction        | 0.00735      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 159          |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.0004      |
# |    value_loss           | 375          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 239          |
# |    time_elapsed         | 9791         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0041490244 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.742       |
# |    explained_variance   | 0.89         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 134          |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 406          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 240          |
# |    time_elapsed         | 9838         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0039116736 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 255          |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 378          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 241         |
# |    time_elapsed         | 9879        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.002196215 |
# |    clip_fraction        | 0.00566     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 191         |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.000285   |
# |    value_loss           | 446         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 242          |
# |    time_elapsed         | 9922         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0014314468 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.701       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 74.4         |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.000641    |
# |    value_loss           | 231          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 243          |
# |    time_elapsed         | 9965         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0009062054 |
# |    clip_fraction        | 0.00398      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.646       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 211          |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.000206    |
# |    value_loss           | 397          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 244          |
# |    time_elapsed         | 10008        |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0023508621 |
# |    clip_fraction        | 0.00911      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 178          |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.000286    |
# |    value_loss           | 377          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 245          |
# |    time_elapsed         | 10053        |
# |    total_timesteps      | 1003520      |
# | train/                  |              |
# |    approx_kl            | 0.0018253762 |
# |    clip_fraction        | 0.00825      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 100          |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.000767    |
# |    value_loss           | 436          |
# ------------------------------------------

# %% [markdown]
# ## Existing model

# %%
# load the model
model_name = "model_1M"
model = PPO.load(f"./saved_models/{model_name}", env=env)

# train the model
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs\PPO_13
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 130  |
# |    iterations      | 1    |
# |    time_elapsed    | 31   |
# |    total_timesteps | 4096 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 2            |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0018236763 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 65           |
# |    n_updates            | 2450         |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 138          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 81            |
# |    iterations           | 3             |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00036639726 |
# |    clip_fraction        | 0.00403       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.605        |
# |    explained_variance   | 0.698         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 54.3          |
# |    n_updates            | 2460          |
# |    policy_gradient_loss | -0.000125     |
# |    value_loss           | 339           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 84            |
# |    iterations           | 4             |
# |    time_elapsed         | 194           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00052227173 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.554        |
# |    explained_variance   | 0.732         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 145           |
# |    n_updates            | 2470          |
# |    policy_gradient_loss | 0.000128      |
# |    value_loss           | 551           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 85            |
# |    iterations           | 5             |
# |    time_elapsed         | 238           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00068742724 |
# |    clip_fraction        | 0.00359       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.482        |
# |    explained_variance   | 0.804         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 171           |
# |    n_updates            | 2480          |
# |    policy_gradient_loss | -0.000599     |
# |    value_loss           | 285           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 87           |
# |    iterations           | 6            |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0016782763 |
# |    clip_fraction        | 0.00959      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 132          |
# |    n_updates            | 2490         |
# |    policy_gradient_loss | -0.000732    |
# |    value_loss           | 398          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 7            |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0013003468 |
# |    clip_fraction        | 0.00823      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0.791        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 116          |
# |    n_updates            | 2500         |
# |    policy_gradient_loss | -0.000107    |
# |    value_loss           | 337          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 8           |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.000295741 |
# |    clip_fraction        | 0.0032      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 179         |
# |    n_updates            | 2510        |
# |    policy_gradient_loss | -0.000111   |
# |    value_loss           | 501         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 9           |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002844553 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 93.4        |
# |    n_updates            | 2520        |
# |    policy_gradient_loss | -0.000804   |
# |    value_loss           | 379         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 10           |
# |    time_elapsed         | 451          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0021483563 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 108          |
# |    n_updates            | 2530         |
# |    policy_gradient_loss | -0.000796    |
# |    value_loss           | 308          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 91            |
# |    iterations           | 11            |
# |    time_elapsed         | 493           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00085092336 |
# |    clip_fraction        | 0.00664       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.565        |
# |    explained_variance   | 0.768         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 197           |
# |    n_updates            | 2540          |
# |    policy_gradient_loss | 0.000134      |
# |    value_loss           | 455           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 12           |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0015159304 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 251          |
# |    n_updates            | 2550         |
# |    policy_gradient_loss | -0.000724    |
# |    value_loss           | 464          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 13           |
# |    time_elapsed         | 579          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0011799993 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.56        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 130          |
# |    n_updates            | 2560         |
# |    policy_gradient_loss | 0.000153     |
# |    value_loss           | 341          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 92            |
# |    iterations           | 14            |
# |    time_elapsed         | 620           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00078137114 |
# |    clip_fraction        | 0.000879      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.57         |
# |    explained_variance   | 0.711         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 327           |
# |    n_updates            | 2570          |
# |    policy_gradient_loss | -0.000539     |
# |    value_loss           | 576           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 15           |
# |    time_elapsed         | 662          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0007461606 |
# |    clip_fraction        | 0.00408      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.623       |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 215          |
# |    n_updates            | 2580         |
# |    policy_gradient_loss | -0.000293    |
# |    value_loss           | 427          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 16           |
# |    time_elapsed         | 706          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0032622218 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.542       |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 214          |
# |    n_updates            | 2590         |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 447          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 17           |
# |    time_elapsed         | 753          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0013321349 |
# |    clip_fraction        | 0.00422      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 123          |
# |    n_updates            | 2600         |
# |    policy_gradient_loss | -3.36e-05    |
# |    value_loss           | 314          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 18           |
# |    time_elapsed         | 800          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0029049874 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 217          |
# |    n_updates            | 2610         |
# |    policy_gradient_loss | -0.000594    |
# |    value_loss           | 527          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 19           |
# |    time_elapsed         | 845          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0008854054 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 389          |
# |    n_updates            | 2620         |
# |    policy_gradient_loss | -0.000484    |
# |    value_loss           | 314          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 20           |
# |    time_elapsed         | 892          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0018804865 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 197          |
# |    n_updates            | 2630         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 390          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 21           |
# |    time_elapsed         | 937          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0011720231 |
# |    clip_fraction        | 0.00627      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.718       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 82.2         |
# |    n_updates            | 2640         |
# |    policy_gradient_loss | -0.000265    |
# |    value_loss           | 223          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 22           |
# |    time_elapsed         | 981          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0014011071 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 366          |
# |    n_updates            | 2650         |
# |    policy_gradient_loss | -0.000255    |
# |    value_loss           | 493          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 23           |
# |    time_elapsed         | 1027         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0021160003 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 396          |
# |    n_updates            | 2660         |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 375          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 24           |
# |    time_elapsed         | 1073         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0035082463 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 90.5         |
# |    n_updates            | 2670         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 359          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 25           |
# |    time_elapsed         | 1120         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0011451773 |
# |    clip_fraction        | 0.00662      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 317          |
# |    n_updates            | 2680         |
# |    policy_gradient_loss | 8.96e-05     |
# |    value_loss           | 451          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 26           |
# |    time_elapsed         | 1165         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0006738527 |
# |    clip_fraction        | 0.00222      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 87.7         |
# |    n_updates            | 2690         |
# |    policy_gradient_loss | 0.000201     |
# |    value_loss           | 375          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 27           |
# |    time_elapsed         | 1213         |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0037862426 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 151          |
# |    n_updates            | 2700         |
# |    policy_gradient_loss | -0.000982    |
# |    value_loss           | 340          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 28           |
# |    time_elapsed         | 1258         |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0009904777 |
# |    clip_fraction        | 0.00381      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.6         |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 190          |
# |    n_updates            | 2710         |
# |    policy_gradient_loss | 1.19e-05     |
# |    value_loss           | 285          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 29           |
# |    time_elapsed         | 1301         |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0008477883 |
# |    clip_fraction        | 0.000952     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0.693        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 371          |
# |    n_updates            | 2720         |
# |    policy_gradient_loss | 0.000403     |
# |    value_loss           | 525          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 30           |
# |    time_elapsed         | 1344         |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0017558944 |
# |    clip_fraction        | 0.00652      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 85.1         |
# |    n_updates            | 2730         |
# |    policy_gradient_loss | -0.000443    |
# |    value_loss           | 473          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 31           |
# |    time_elapsed         | 1385         |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0035936534 |
# |    clip_fraction        | 0.00833      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.612       |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 222          |
# |    n_updates            | 2740         |
# |    policy_gradient_loss | -0.000311    |
# |    value_loss           | 461          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 32           |
# |    time_elapsed         | 1429         |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0023012226 |
# |    clip_fraction        | 0.00525      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | 0.714        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 278          |
# |    n_updates            | 2750         |
# |    policy_gradient_loss | -0.000761    |
# |    value_loss           | 466          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 33           |
# |    time_elapsed         | 1472         |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0013091897 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 78.5         |
# |    n_updates            | 2760         |
# |    policy_gradient_loss | -0.000611    |
# |    value_loss           | 476          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 34           |
# |    time_elapsed         | 1516         |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0012304722 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.759        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 124          |
# |    n_updates            | 2770         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 357          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 35           |
# |    time_elapsed         | 1562         |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0007127521 |
# |    clip_fraction        | 0.00359      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.415       |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 605          |
# |    n_updates            | 2780         |
# |    policy_gradient_loss | -0.000424    |
# |    value_loss           | 561          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 36           |
# |    time_elapsed         | 1603         |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0012937547 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.724        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 191          |
# |    n_updates            | 2790         |
# |    policy_gradient_loss | -0.000484    |
# |    value_loss           | 375          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 37          |
# |    time_elapsed         | 1647        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.001060506 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.399      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 243         |
# |    n_updates            | 2800        |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 352         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 92            |
# |    iterations           | 38            |
# |    time_elapsed         | 1690          |
# |    total_timesteps      | 155648        |
# | train/                  |               |
# |    approx_kl            | 0.00048704282 |
# |    clip_fraction        | 0.0033        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.418        |
# |    explained_variance   | 0.695         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 318           |
# |    n_updates            | 2810          |
# |    policy_gradient_loss | -0.000286     |
# |    value_loss           | 483           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 39           |
# |    time_elapsed         | 1734         |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0003283975 |
# |    clip_fraction        | 0.00422      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.418       |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 120          |
# |    n_updates            | 2820         |
# |    policy_gradient_loss | 0.000103     |
# |    value_loss           | 306          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 40           |
# |    time_elapsed         | 1779         |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0016407149 |
# |    clip_fraction        | 0.00979      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 198          |
# |    n_updates            | 2830         |
# |    policy_gradient_loss | -0.000735    |
# |    value_loss           | 405          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 41          |
# |    time_elapsed         | 1819        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.001965545 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 203         |
# |    n_updates            | 2840        |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 389         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 42           |
# |    time_elapsed         | 1862         |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0028675438 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 137          |
# |    n_updates            | 2850         |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 226          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 43           |
# |    time_elapsed         | 1904         |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0024863125 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 437          |
# |    n_updates            | 2860         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 528          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 44           |
# |    time_elapsed         | 1949         |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0042703673 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 103          |
# |    n_updates            | 2870         |
# |    policy_gradient_loss | -0.00091     |
# |    value_loss           | 295          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 45           |
# |    time_elapsed         | 1990         |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0008535994 |
# |    clip_fraction        | 0.00232      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 164          |
# |    n_updates            | 2880         |
# |    policy_gradient_loss | 0.000165     |
# |    value_loss           | 340          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 46          |
# |    time_elapsed         | 2033        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.002968332 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 222         |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 579         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 47           |
# |    time_elapsed         | 2080         |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0014057355 |
# |    clip_fraction        | 0.00774      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 83.5         |
# |    n_updates            | 2900         |
# |    policy_gradient_loss | -0.000317    |
# |    value_loss           | 322          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 92            |
# |    iterations           | 48            |
# |    time_elapsed         | 2124          |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00083911966 |
# |    clip_fraction        | 0.00559       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.485        |
# |    explained_variance   | 0.825         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 164           |
# |    n_updates            | 2910          |
# |    policy_gradient_loss | -0.000744     |
# |    value_loss           | 303           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 49           |
# |    time_elapsed         | 2169         |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0007629632 |
# |    clip_fraction        | 0.00261      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 510          |
# |    n_updates            | 2920         |
# |    policy_gradient_loss | 3.16e-05     |
# |    value_loss           | 543          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 50           |
# |    time_elapsed         | 2212         |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0036345026 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.822        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 179          |
# |    n_updates            | 2930         |
# |    policy_gradient_loss | -0.000537    |
# |    value_loss           | 346          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 51           |
# |    time_elapsed         | 2255         |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0012186475 |
# |    clip_fraction        | 0.00671      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.461       |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 160          |
# |    n_updates            | 2940         |
# |    policy_gradient_loss | -0.00076     |
# |    value_loss           | 389          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 52           |
# |    time_elapsed         | 2298         |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0016749494 |
# |    clip_fraction        | 0.00906      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 543          |
# |    n_updates            | 2950         |
# |    policy_gradient_loss | -0.000274    |
# |    value_loss           | 521          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 53           |
# |    time_elapsed         | 2343         |
# |    total_timesteps      | 217088       |
# | train/                  |              |
# |    approx_kl            | 0.0022246637 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 154          |
# |    n_updates            | 2960         |
# |    policy_gradient_loss | -0.00087     |
# |    value_loss           | 410          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 54           |
# |    time_elapsed         | 2386         |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0020701687 |
# |    clip_fraction        | 0.00388      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 150          |
# |    n_updates            | 2970         |
# |    policy_gradient_loss | -0.000382    |
# |    value_loss           | 291          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 92            |
# |    iterations           | 55            |
# |    time_elapsed         | 2428          |
# |    total_timesteps      | 225280        |
# | train/                  |               |
# |    approx_kl            | 0.00045539916 |
# |    clip_fraction        | 0.00293       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.602        |
# |    explained_variance   | 0.901         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 73.8          |
# |    n_updates            | 2980          |
# |    policy_gradient_loss | -0.000466     |
# |    value_loss           | 358           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 56           |
# |    time_elapsed         | 2470         |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0019495588 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 96.3         |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 341          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 57           |
# |    time_elapsed         | 2513         |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0007853168 |
# |    clip_fraction        | 0.00759      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 292          |
# |    n_updates            | 3000         |
# |    policy_gradient_loss | 0.00015      |
# |    value_loss           | 224          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 93            |
# |    iterations           | 58            |
# |    time_elapsed         | 2553          |
# |    total_timesteps      | 237568        |
# | train/                  |               |
# |    approx_kl            | 0.00036558704 |
# |    clip_fraction        | 0.0031        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.639        |
# |    explained_variance   | 0.892         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 165           |
# |    n_updates            | 3010          |
# |    policy_gradient_loss | 0.00022       |
# |    value_loss           | 440           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 59          |
# |    time_elapsed         | 2600        |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.001894629 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 317         |
# |    n_updates            | 3020        |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 399         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 60           |
# |    time_elapsed         | 2644         |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0015090543 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.727       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 140          |
# |    n_updates            | 3030         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 280          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 61           |
# |    time_elapsed         | 2687         |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0018982554 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 129          |
# |    n_updates            | 3040         |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 240          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 62           |
# |    time_elapsed         | 2733         |
# |    total_timesteps      | 253952       |
# | train/                  |              |
# |    approx_kl            | 0.0009798122 |
# |    clip_fraction        | 0.00437      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.723       |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 149          |
# |    n_updates            | 3050         |
# |    policy_gradient_loss | -0.000169    |
# |    value_loss           | 368          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 63           |
# |    time_elapsed         | 2778         |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0027746647 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.477       |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 143          |
# |    n_updates            | 4680         |
# |    policy_gradient_loss | 0.000131     |
# |    value_loss           | 404          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 226          |
# |    time_elapsed         | 37749        |
# |    total_timesteps      | 925696       |
# | train/                  |              |
# |    approx_kl            | 0.0016259715 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 153          |
# |    n_updates            | 4690         |
# |    policy_gradient_loss | -0.000791    |
# |    value_loss           | 533          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 227          |
# |    time_elapsed         | 37794        |
# |    total_timesteps      | 929792       |
# | train/                  |              |
# |    approx_kl            | 0.0019238603 |
# |    clip_fraction        | 0.00818      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.428       |
# |    explained_variance   | 0.921        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 77           |
# |    n_updates            | 4700         |
# |    policy_gradient_loss | -0.00065     |
# |    value_loss           | 277          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 228          |
# |    time_elapsed         | 37841        |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0023453627 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 134          |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | 0.000225     |
# |    value_loss           | 350          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 229          |
# |    time_elapsed         | 37885        |
# |    total_timesteps      | 937984       |
# | train/                  |              |
# |    approx_kl            | 0.0007227077 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.437       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 219          |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | 2.15e-05     |
# |    value_loss           | 338          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 230          |
# |    time_elapsed         | 37932        |
# |    total_timesteps      | 942080       |
# | train/                  |              |
# |    approx_kl            | 0.0025768604 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.46        |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 169          |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.000814    |
# |    value_loss           | 484          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 231          |
# |    time_elapsed         | 37977        |
# |    total_timesteps      | 946176       |
# | train/                  |              |
# |    approx_kl            | 0.0017015192 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.862        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 89.4         |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | 0.00205      |
# |    value_loss           | 494          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 232          |
# |    time_elapsed         | 38024        |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0037486707 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.454       |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 92.1         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | 0.000995     |
# |    value_loss           | 242          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 233          |
# |    time_elapsed         | 38069        |
# |    total_timesteps      | 954368       |
# | train/                  |              |
# |    approx_kl            | 0.0013764192 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 210          |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.00064     |
# |    value_loss           | 456          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 234          |
# |    time_elapsed         | 38114        |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0013895817 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 141          |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.000134    |
# |    value_loss           | 541          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 235          |
# |    time_elapsed         | 38161        |
# |    total_timesteps      | 962560       |
# | train/                  |              |
# |    approx_kl            | 0.0013154682 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.467       |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 301          |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | 7.03e-05     |
# |    value_loss           | 396          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 236          |
# |    time_elapsed         | 38206        |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0014284467 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.417       |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 39.4         |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.000289    |
# |    value_loss           | 203          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 237          |
# |    time_elapsed         | 38253        |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0017905862 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 105          |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 0.000685     |
# |    value_loss           | 384          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 238         |
# |    time_elapsed         | 38299       |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.002117358 |
# |    clip_fraction        | 0.00469     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 166         |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.000866   |
# |    value_loss           | 353         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 239          |
# |    time_elapsed         | 38348        |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0026062175 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 124          |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | 0.000716     |
# |    value_loss           | 354          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 240          |
# |    time_elapsed         | 38396        |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0022579634 |
# |    clip_fraction        | 0.00774      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 145          |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | 6.27e-05     |
# |    value_loss           | 373          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 241          |
# |    time_elapsed         | 38443        |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0026889609 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 300          |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.000284    |
# |    value_loss           | 480          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 242          |
# |    time_elapsed         | 38490        |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0018965501 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.448       |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 116          |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00036     |
# |    value_loss           | 263          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 243         |
# |    time_elapsed         | 38534       |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.008317534 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 181         |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 534         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 244          |
# |    time_elapsed         | 38579        |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0039682337 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 125          |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | 0.00318      |
# |    value_loss           | 332          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 245          |
# |    time_elapsed         | 38624        |
# |    total_timesteps      | 1003520      |
# | train/                  |              |
# |    approx_kl            | 0.0034407824 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 94.2         |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.000645    |
# |    value_loss           | 428          |
# ------------------------------------------

# %% [markdown]
# # 4. Testing the model

# %%
# Base environment
env = gym.make('SuperMarioBros-v0', apply_api_compatibility=True, render_mode="human")
# Simplify controls
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# Grayscale observation
env = GrayScaleObservation(env, keep_dim=True)
# Wrap inside the dummy vector environment
env = DummyVecEnv([lambda: env])
# Stack 4 frames
env = VecFrameStack(env, n_stack=FRAME_STACK_SIZE, channels_order='last')
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
# load the model
model = PPO.load(os.path.join(CHECKPOINT_DIR, "model_120000.zip"), env=env)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # load the model
# ----> 2 model = PPO.load(os.path.join(CHECKPOINT_DIR, "model_120000.zip"), env=env)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\base_class.py:677, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     674     print("== CURRENT SYSTEM INFO ==")
#     675     get_system_info()
# --> 677 data, params, pytorch_variables = load_from_zip_file(
#     678     path,
#     679     device=device,
#     680     custom_objects=custom_objects,
#     681     print_system_info=print_system_info,
#     682 )
#     684 assert data is not None, "No data found in the saved file"
#     685 assert params is not None, "No params found in the saved file"
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\save_util.py:402, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     375 def load_from_zip_file(
#     376     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     377     load_data: bool = True,
#    (...)
#     381     print_system_info: bool = False,
#     382 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     383     """
#     384     Load model data from a .zip archive
#     385
#    (...)
#     400         and dict of pytorch variables
#     401     """
# --> 402     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     404     # set device to cpu if cuda is not available
#     405     device = get_device(device=device)
#
# File c:\Users\hugof\.pyenv\pyenv-win\versions\3.10.11\lib\functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\save_util.py:239, in open_path_str(path, mode, verbose, suffix)
#     224 @open_path.register(str)
#     225 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     226     """
#     227     Open a path given by a string. If writing to the path, the function ensures
#     228     that the path exists.
#    (...)
#     237     :return:
#     238     """
# --> 239     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\save_util.py:290, in open_path_pathlib(path, mode, verbose, suffix)
#     284         path.parent.mkdir(exist_ok=True, parents=True)
#     286 # if opening was successful uses the open_path() function
#     287 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     288 #   with corrections
#     289 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 290 return open_path_pathlib(path, mode, verbose, suffix)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\save_util.py:271, in open_path_pathlib(path, mode, verbose, suffix)
#     269             path, suffix = newpath, None
#     270         else:
# --> 271             raise error
#     272 else:
#     273     try:
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\save_util.py:263, in open_path_pathlib(path, mode, verbose, suffix)
#     261 if mode == "r":
#     262     try:
# --> 263         return open_path(path.open("rb"), mode, verbose, suffix)
#     264     except FileNotFoundError as error:
#     265         if suffix is not None and suffix != "":
#
# File c:\Users\hugof\.pyenv\pyenv-win\versions\3.10.11\lib\pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train\\model_120000.zip.zip'

# %%
# load a saved model
model = PPO.load(os.path.join("./saved_models", "Mario-1M.zip"), env=env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
# start the game with the trained model
state = env.reset()
for i in range(10000):
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
env.close()
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:272: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(
