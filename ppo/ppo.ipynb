# %% [markdown]
# # 1. Setup Mario
# Basic mario environment setup, with random actions.

# %%
from nes_py.wrappers import JoypadSpace
import gym
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
env = gym.make('SuperMarioBros-v0', apply_api_compatibility=True, render_mode="human")
env = JoypadSpace(env, SIMPLE_MOVEMENT)

done = True
for step in range(2000):
    if done:
       state = env.reset()
    action = env.action_space.sample()
    state, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
env.close()
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %% [markdown]
# # 2. Preprocessing Data

# %% [markdown]
# ## 2.1 What the environment is giving us

# %%
# Number of possible actions the AI can make
env.action_space
# Out:
# Discrete(7)

# %%
# The format returned by the environment : A colored frame
env.observation_space.shape
# Out:
# (240, 256, 3)

# %% [markdown]
# ## 2.2 What we want
# - Turn the image into grayscale
# - Save a stack of 4 images to give context to the model

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# %pip install stable-baselines3[extra]
# %pip install matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from nes_py.wrappers import JoypadSpace
JoypadSpace.reset = lambda self, **kwargs: self.env.reset(**kwargs)
import gym
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed
from matplotlib import pyplot as plt

# %%
FRAME_STACK_SIZE = 4

# %% [markdown]
# Basic environment

# %%
# Base environment
env = gym.make('SuperMarioBros-v0', apply_api_compatibility=True)
# Simplify controls
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# Grayscale observation
env = GrayScaleObservation(env, keep_dim=True)
# Wrap inside the dummy vector environment
env = DummyVecEnv([lambda: env])
# Stack 4 frames
env = VecFrameStack(env, n_stack=FRAME_STACK_SIZE, channels_order='last')
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# Multiprocessed environment

# %%
env_id = "SuperMarioBros-v0"
num_processes = 8

# %%
def make_env(env_id: str, rank: int, seed: int = None):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = gym.make(env_id, apply_api_compatibility=True)
        env = JoypadSpace(env, SIMPLE_MOVEMENT)
        env = GrayScaleObservation(env, keep_dim=True)
        return env
    return _init

# %%
# Create n environments
env = DummyVecEnv([make_env(env_id, i) for i in range(num_processes)])
# Stack 4 frames
env = VecFrameStack(env, n_stack=FRAME_STACK_SIZE, channels_order='last')
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
state = env.reset()
state[0].shape
# Out:
# (240, 256, 4)

# %%
action = env.action_space.sample()
state, reward, done, info = env.step([action])
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 action = env.action_space.sample()
# ----> 2 state, reward, done, info = env.step([action])
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:33, in VecFrameStack.step_wait(self)
#      30 def step_wait(
#      31     self,
#      32 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 33     observations, rewards, dones, infos = self.venv.step_wait()
#      34     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      35     return observations, rewards, dones, infos
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
#      58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# IndexError: list index out of range

# %%
# show the 4 current frames
plt.figure(figsize=(10, 8))
for idk in range(state.shape[3]):
    plt.subplot(1, 4, idk + 1)
    plt.imshow(state[0, :, :, idk], cmap='gray')
plt.show()

# %% [markdown]
# # 3. Training the model

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback

# %%
# class to automatically save models while training
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
    
    def _init_callback(self) -> None:
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            self.model.save(os.path.join(self.save_path, f"model_{self.n_calls * num_processes}"))
        
        return True

# %%
CHECKPOINT_DIR = "./train"
LOG_DIR = "./logs"

# %%
# setup the callback
callback = TrainAndLoggingCallback(check_freq=10000 / num_processes, save_path=CHECKPOINT_DIR)

# %%
# create the model
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, n_steps=512)

# train the model
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 302  |
# |    iterations      | 1    |
# |    time_elapsed    | 13   |
# |    total_timesteps | 4096 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 2            |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0009067947 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.000967    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 93.7         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000532    |
# |    value_loss           | 251          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 3            |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0012572967 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 11.3         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 31           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 4            |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0023483527 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.176        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.699        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 114           |
# |    iterations           | 5             |
# |    time_elapsed         | 179           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00013369953 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.183         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.595         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000306     |
# |    value_loss           | 12.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 6            |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 1.805344e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 10.5         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 1.4e-06      |
# |    value_loss           | 57.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 7             |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00013303995 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.335         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 8.24          |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000331     |
# |    value_loss           | 13.9          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 8            |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0043281056 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.103        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 0.351        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 9           |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002870314 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0895      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 0.335       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 10           |
# |    time_elapsed         | 376          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0020248545 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.137        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 0.257        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 11          |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004103304 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0568      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 0.2         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 12           |
# |    time_elapsed         | 458          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0015015907 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.074        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 0.179        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 106           |
# |    iterations           | 13            |
# |    time_elapsed         | 500           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00072298886 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.87         |
# |    explained_variance   | 0.76          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0405        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000436     |
# |    value_loss           | 0.141         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 14           |
# |    time_elapsed         | 540          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0023698434 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0675       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 0.151        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 15           |
# |    time_elapsed         | 580          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0013822282 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.651        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0505       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 0.129        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 16           |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0001978941 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.38         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00031     |
# |    value_loss           | 8.75         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 17           |
# |    time_elapsed         | 660          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0043144464 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 21.4         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000753    |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 18          |
# |    time_elapsed         | 699         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003383495 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 38          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00153     |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 19          |
# |    time_elapsed         | 738         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.003761164 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.257       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 0.61        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 20           |
# |    time_elapsed         | 778          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0016802168 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.137        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000901    |
# |    value_loss           | 0.471        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 21            |
# |    time_elapsed         | 816           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00054609566 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.8          |
# |    explained_variance   | 0.902         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.31          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000517     |
# |    value_loss           | 2.07          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 22            |
# |    time_elapsed         | 855           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00093667663 |
# |    clip_fraction        | 0.000562      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.78         |
# |    explained_variance   | 0.714         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 17.8          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | 0.000267      |
# |    value_loss           | 40.5          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 23            |
# |    time_elapsed         | 894           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00029955656 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.77         |
# |    explained_variance   | 0.663         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 18.4          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00034      |
# |    value_loss           | 28.9          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 24           |
# |    time_elapsed         | 934          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0023961978 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.11         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000597    |
# |    value_loss           | 0.453        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 25          |
# |    time_elapsed         | 972         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.001264153 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.11        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000521   |
# |    value_loss           | 0.381       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 26           |
# |    time_elapsed         | 1009         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0008752188 |
# |    clip_fraction        | 0.00022      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 8.5          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000808    |
# |    value_loss           | 34.9         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 27            |
# |    time_elapsed         | 1046          |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00042560455 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.76         |
# |    explained_variance   | 0.894         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.816         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000169     |
# |    value_loss           | 16            |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 28          |
# |    time_elapsed         | 1082        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.009743888 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0696      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 0.237       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 29           |
# |    time_elapsed         | 1120         |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0064799767 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0569       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 0.207        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 30           |
# |    time_elapsed         | 1158         |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0074101253 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0729       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 0.174        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 31          |
# |    time_elapsed         | 1197        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.006781543 |
# |    clip_fraction        | 0.00559     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.017       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 32          |
# |    time_elapsed         | 1235        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004716103 |
# |    clip_fraction        | 0.00503     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.101       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 33          |
# |    time_elapsed         | 1275        |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.004839544 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 71.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000157   |
# |    value_loss           | 141         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 34           |
# |    time_elapsed         | 1314         |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0006295301 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.852        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 50.8         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000428    |
# |    value_loss           | 108          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 35            |
# |    time_elapsed         | 1355          |
# |    total_timesteps      | 143360        |
# | train/                  |               |
# |    approx_kl            | 0.00023058782 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.49         |
# |    explained_variance   | 0.931         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.73          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000413     |
# |    value_loss           | 16            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 36           |
# |    time_elapsed         | 1395         |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0010653976 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.202        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000654    |
# |    value_loss           | 0.323        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 37           |
# |    time_elapsed         | 1435         |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0014149051 |
# |    clip_fraction        | 0.000708     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.79         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 9.74e-05     |
# |    value_loss           | 27.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 38           |
# |    time_elapsed         | 1472         |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0061747413 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0961       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 1.3          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 39           |
# |    time_elapsed         | 1511         |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0022679865 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0654       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000687    |
# |    value_loss           | 0.21         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 40           |
# |    time_elapsed         | 1549         |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0046131792 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0766       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.183        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 41           |
# |    time_elapsed         | 1588         |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0068595186 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.067        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 0.176        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 42           |
# |    time_elapsed         | 1626         |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0024083587 |
# |    clip_fraction        | 0.00408      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.46         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 22.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 43           |
# |    time_elapsed         | 1664         |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0105830915 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0801       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 44           |
# |    time_elapsed         | 1703         |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0014788194 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0797       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000204    |
# |    value_loss           | 0.149        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 45          |
# |    time_elapsed         | 1741        |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.005409628 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0504      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 0.141       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 46           |
# |    time_elapsed         | 1780         |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0024003887 |
# |    clip_fraction        | 0.00271      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0519       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 0.144        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 47          |
# |    time_elapsed         | 1819        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.012782609 |
# |    clip_fraction        | 0.00405     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0174      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 0.141       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 48           |
# |    time_elapsed         | 1857         |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0012179121 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0959       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000678    |
# |    value_loss           | 1.97         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 49           |
# |    time_elapsed         | 1896         |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0023314115 |
# |    clip_fraction        | 0.00305      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 52.7         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0005      |
# |    value_loss           | 204          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 50           |
# |    time_elapsed         | 1934         |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0004181997 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 26.1         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000505    |
# |    value_loss           | 58           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 51           |
# |    time_elapsed         | 1974         |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0015127349 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.439        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000801    |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 52           |
# |    time_elapsed         | 2015         |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0040483186 |
# |    clip_fraction        | 0.00168      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.386        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 2.39         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 53          |
# |    time_elapsed         | 2055        |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.003255208 |
# |    clip_fraction        | 0.000415    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 22.1        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 26          |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 54            |
# |    time_elapsed         | 2093          |
# |    total_timesteps      | 221184        |
# | train/                  |               |
# |    approx_kl            | 0.00056265964 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.909         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.61          |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000253     |
# |    value_loss           | 23            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 55           |
# |    time_elapsed         | 2132         |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0026697342 |
# |    clip_fraction        | 0.00818      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0808       |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00072     |
# |    value_loss           | 0.237        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 56           |
# |    time_elapsed         | 2171         |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0011331781 |
# |    clip_fraction        | 2.44e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.895        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.2          |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000159    |
# |    value_loss           | 0.24         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 57          |
# |    time_elapsed         | 2209        |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.006167875 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.083       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 0.224       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 58           |
# |    time_elapsed         | 2248         |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0004693277 |
# |    clip_fraction        | 0.000171     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.366        |
# |    n_updates            | 570          |
# |    policy_gradient_loss | 0.000776     |
# |    value_loss           | 28           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 59          |
# |    time_elapsed         | 2285        |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.010046699 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.115       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 0.643       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 105           |
# |    iterations           | 60            |
# |    time_elapsed         | 2323          |
# |    total_timesteps      | 245760        |
# | train/                  |               |
# |    approx_kl            | 0.00017767526 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | 0.914         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.34          |
# |    n_updates            | 590           |
# |    policy_gradient_loss | 0.000314      |
# |    value_loss           | 14.2          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 61           |
# |    time_elapsed         | 2361         |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0083985515 |
# |    clip_fraction        | 0.00676      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0656       |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 0.185        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 62          |
# |    time_elapsed         | 2398        |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.013236281 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0777      |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 0.172       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 63           |
# |    time_elapsed         | 2438         |
# |    total_timesteps      | 258048       |
# | train/                  |              |
# |    approx_kl            | 0.0032645692 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.544        |
# |    learning_rate        | 1e-06        |
# ...
# |    time_elapsed         | 8956        |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.000463382 |
# |    clip_fraction        | 0.0033      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.934       |
# |    n_updates            | 2240        |
# |    policy_gradient_loss | -0.000658   |
# |    value_loss           | 6.92        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 226          |
# |    time_elapsed         | 8996         |
# |    total_timesteps      | 925696       |
# | train/                  |              |
# |    approx_kl            | 0.0033577038 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.509       |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.07         |
# |    n_updates            | 2250         |
# |    policy_gradient_loss | -0.000381    |
# |    value_loss           | 2.18         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 227           |
# |    time_elapsed         | 9036          |
# |    total_timesteps      | 929792        |
# | train/                  |               |
# |    approx_kl            | 0.00021011218 |
# |    clip_fraction        | 0.000342      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.49         |
# |    explained_variance   | 0.977         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 125           |
# |    n_updates            | 2260          |
# |    policy_gradient_loss | -6.37e-05     |
# |    value_loss           | 128           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 228           |
# |    time_elapsed         | 9078          |
# |    total_timesteps      | 933888        |
# | train/                  |               |
# |    approx_kl            | 0.00022329671 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.472        |
# |    explained_variance   | 0.96          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 117           |
# |    n_updates            | 2270          |
# |    policy_gradient_loss | -8.66e-05     |
# |    value_loss           | 287           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 229          |
# |    time_elapsed         | 9118         |
# |    total_timesteps      | 937984       |
# | train/                  |              |
# |    approx_kl            | 0.0015220165 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 41           |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.000295    |
# |    value_loss           | 185          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 230          |
# |    time_elapsed         | 9156         |
# |    total_timesteps      | 942080       |
# | train/                  |              |
# |    approx_kl            | 0.0014685596 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 34.5         |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.000681    |
# |    value_loss           | 191          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 231          |
# |    time_elapsed         | 9195         |
# |    total_timesteps      | 946176       |
# | train/                  |              |
# |    approx_kl            | 0.0037803622 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 86.6         |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 224          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 232          |
# |    time_elapsed         | 9234         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0024794873 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 160          |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.000542    |
# |    value_loss           | 121          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 233         |
# |    time_elapsed         | 9275        |
# |    total_timesteps      | 954368      |
# | train/                  |             |
# |    approx_kl            | 0.004226976 |
# |    clip_fraction        | 0.0121      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 60.3        |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.000978   |
# |    value_loss           | 162         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 234         |
# |    time_elapsed         | 9314        |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.009635213 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 97.1        |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 240         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 235          |
# |    time_elapsed         | 9353         |
# |    total_timesteps      | 962560       |
# | train/                  |              |
# |    approx_kl            | 0.0056281947 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 92.7         |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.000579    |
# |    value_loss           | 294          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 236          |
# |    time_elapsed         | 9393         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 6.516493e-05 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.648       |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 162          |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | 6.01e-05     |
# |    value_loss           | 283          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 237         |
# |    time_elapsed         | 9432        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.005233879 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 125         |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00047    |
# |    value_loss           | 238         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 238         |
# |    time_elapsed         | 9472        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.005742507 |
# |    clip_fraction        | 0.000488    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 178         |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.000745    |
# |    value_loss           | 306         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 239          |
# |    time_elapsed         | 9511         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0020596625 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 192          |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | 0.000153     |
# |    value_loss           | 212          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 240          |
# |    time_elapsed         | 9551         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0055646794 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.584       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.11         |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 173          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 241         |
# |    time_elapsed         | 9592        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.002442258 |
# |    clip_fraction        | 0.00735     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 1e-06       |
# |    loss                 | 37.8        |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.000585   |
# |    value_loss           | 127         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 242          |
# |    time_elapsed         | 9632         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0069084587 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.651       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 209          |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 164          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 243         |
# |    time_elapsed         | 9673        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.008922886 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 89          |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 164         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 244         |
# |    time_elapsed         | 9712        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.010099271 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.655      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 17.3        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 135         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 102         |
# |    iterations           | 245         |
# |    time_elapsed         | 9751        |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.009636948 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 74.5        |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00271    |
# |    value_loss           | 169         |
# -----------------------------------------

# %%
model_name = "Mario-1M"
model.save(f"./saved_models/{model_name}")
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\save_util.py:283: UserWarning: Path 'saved_models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# # 4. Testing the model

# %%
# Base environment
env = gym.make('SuperMarioBros-v0', apply_api_compatibility=True, render_mode="human")
# Simplify controls
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# Grayscale observation
env = GrayScaleObservation(env, keep_dim=True)
# Wrap inside the dummy vector environment
env = DummyVecEnv([lambda: env])
# Stack 4 frames
env = VecFrameStack(env, n_stack=FRAME_STACK_SIZE, channels_order='last')
# Out:
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
# load the model
model = PPO.load(os.path.join(CHECKPOINT_DIR, "model_120000.zip"), env=env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
# load a saved model
model = PPO.load(os.path.join("./saved_models", "Mario-1M.zip"), env=env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
# start the game with the trained model
state = env.reset()
for i in range(10000):
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 state = env.reset()
#       3 for i in range(10000):
# ----> 4     action, _ = model.predict(state)
#       5     state, reward, done, info = env.step(action)
#       6     env.render()
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\base_class.py:553, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     533 def predict(
#     534     self,
#     535     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     538     deterministic: bool = False,
#     539 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     540     """
#     541     Get the policy action from an observation (and optional hidden state).
#     542     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     551         (used in recurrent policies)
#     552     """
# --> 553     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\policies.py:366, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     363 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     365 with th.no_grad():
# --> 366     actions = self._predict(obs_tensor, deterministic=deterministic)
#     367 # Convert to numpy, and reshape to the original action shape
#     368 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\policies.py:715, in ActorCriticPolicy._predict(self, observation, deterministic)
#     707 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#     708     """
#     709     Get the action according to the policy for a given observation.
#     710
#    (...)
#     713     :return: Taken action according to the policy
#     714     """
# --> 715     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\policies.py:748, in ActorCriticPolicy.get_distribution(self, obs)
#     741 def get_distribution(self, obs: PyTorchObs) -> Distribution:
#     742     """
#     743     Get the current policy distribution given the observations.
#     744
#     745     :param obs:
#     746     :return: the action distribution.
#     747     """
# --> 748     features = super().extract_features(obs, self.pi_features_extractor)
#     749     latent_pi = self.mlp_extractor.forward_actor(features)
#     750     return self._get_action_dist_from_latent(latent_pi)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\policies.py:131, in BaseModel.extract_features(self, obs, features_extractor)
#     123 """
#     124 Preprocess the observation if needed and extract features.
#     125
#    (...)
#     128 :return: The extracted features
#     129 """
#     130 preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 131 return features_extractor(preprocessed_obs)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\stable_baselines3\common\torch_layers.py:106, in NatureCNN.forward(self, observations)
#     105 def forward(self, observations: th.Tensor) -> th.Tensor:
# --> 106     return self.linear(self.cnn(observations))
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File d:\Documents\E5e\Reinforced-Mario\.venv\lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
